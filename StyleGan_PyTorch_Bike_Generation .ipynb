# %% [markdown]
# # Psych2Face: StyleGAN2, PyTorch Bike Implementation

# %% [markdown]
# ## Setup: Check for GPU and Set Directory

# %% [markdown]
# Check for GPU version assigned by Google Colab

# %%
# !nvidia-smi -L
# Out:
# GPU 0: A100-SXM4-40GB (UUID: GPU-435e272f-9cd1-e6de-c0e4-7efad39a81cb)

# %% [markdown]
# Set up directory for Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ## Install SG2-ADA-PyTorch repo to Google Drive.

# %%
# Clone and import the rep as necessary

import os
# !pip install gdown --upgrade

if os.path.isdir("/content/drive/MyDrive/colab-sg2-ada-pytorch"):
    # %cd "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch"
elif os.path.isdir("/content/drive/"):
    #install script
    # %cd "/content/drive/MyDrive/"
    # !mkdir colab-sg2-ada-pytorch
    # %cd colab-sg2-ada-pytorch
    # !git clone https://github.com/dvschultz/stylegan2-ada-pytorch
    # %cd stylegan2-ada-pytorch
    # !mkdir downloads
    # !mkdir datasets
    # !mkdir pretrained
    # !gdown --id 1-5xZkD8ajXw1DdopTkH_rAoCsD72LhKU -O /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/pretrained/wikiart.pkl
else:
    # !git clone https://github.com/dvschultz/stylegan2-ada-pytorch
    # %cd stylegan2-ada-pytorch
    # !mkdir downloads
    # !mkdir datasets
    # !mkdir pretrained
    # %cd pretrained
    # !gdown --id 1-5xZkD8ajXw1DdopTkH_rAoCsD72LhKU
    # %cd ../
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Attempting uninstall: gdown
#     Found existing installation: gdown 4.4.0
#     Uninstalling gdown-4.4.0:
#       Successfully uninstalled gdown-4.4.0
# ...
# /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch

# %% [markdown]
# ### Ensure that PyTorch is up to date as desired

# %%
#Uninstall new JAX
# !pip uninstall jax jaxlib -y
# !pip install "jax[cuda11_cudnn805]==0.3.10" -f https://storage.googleapis.com/jax-releases/jax_cuda_releases.html

#Downgrade Pytorch
# !pip uninstall torch torchvision -y
# !pip install torch==1.9.0+cu111 torchvision==0.10.0+cu111 -f https://download.pytorch.org/whl/torch_stable.html
# !pip install timm==0.4.12 ftfy==6.1.1 ninja==1.10.2 opensimplex

# !pip install torch==1.8.1 torchvision==0.9.1
# !git clone https://github.com/NVlabs/stylegan2-ada-pytorch.git
# !pip install ninja
# Out:
# Found existing installation: jax 0.3.25
# Uninstalling jax-0.3.25:
#   Successfully uninstalled jax-0.3.25
# Found existing installation: jaxlib 0.3.25+cuda11.cudnn805
# Uninstalling jaxlib-0.3.25+cuda11.cudnn805:
#   Successfully uninstalled jaxlib-0.3.25+cuda11.cudnn805
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://storage.googleapis.com/jax-releases/jax_cuda_releases.html
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 939.7/939.7 KB 14.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.6/175.6 MB 10.0 MB/s eta 0:00:00
# ...
#   Created wheel for jax: filename=jax-0.3.10-py3-none-any.whl size=1088066 sha256=6097e4e6321197b21573d7c70582bdbb49c801ae8a9c4700f7a26ffea66df70a
#   Stored in directory: /root/.cache/pip/wheels/d6/47/10/cbe355213ac14e3fb3cf4ebee40eb28f264cbb45588c78c629
# Successfully built jax
# ...

# %% [markdown]
# ## Update Repo as Necessary

# %%
# Get the sg2 repo
# %cd "/content/drive/My Drive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch"
# !git config --global user.name "test"
# !git config --global user.email "test@test.com"
# !git fetch origin
# !git pull
# !git stash
# !git checkout origin/main -- train.py generate.py legacy.py closed_form_factorization.py flesh_digression.py apply_factor.py README.md calc_metrics.py training/stylegan2_multi.py training/training_loop.py util/utilgan.py
# Out:
# /content/drive/My Drive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch
# Already up to date.
# Saved working directory and index state WIP on main: 59e05bb added opensimplex

# %% [markdown]
# ## Train model

# %% [markdown]
# Define path to our dataset, the .pkl file to resume our training procedure, and establish the aug strength based on the last training step.

# %%
import os

# Modify as necessary
EXPERIMENTS = "/content/drive/MyDrive/shoes_folder"
DATA = "/content/drive/MyDrive/training_data"
SNAP = 25

# Build the command and run it
cmd = f"/usr/bin/python3 /content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/train.py --snap {SNAP} --outdir {EXPERIMENTS} --data {DATA}"
# !{cmd}
# Out:
# /usr/local/lib/python3.8/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/colab-sg2-ada-pytorch/stylegan2-ada-pytorch/train.py", line 582, in <module>
#     main() # pylint: disable=no-value-for-parameter
#   File "/usr/local/lib/python3.8/dist-packages/click/core.py", line 829, in __call__
#     return self.main(*args, **kwargs)
#   File "/usr/local/lib/python3.8/dist-packages/click/core.py", line 782, in main
#     rv = self.invoke(ctx)
#   File "/usr/local/lib/python3.8/dist-packages/click/core.py", line 1066, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#   File "/usr/local/lib/python3.8/dist-packages/click/core.py", line 610, in invoke
#     return callback(*args, **kwargs)
# ...

# %%
# !/usr/bin/python3 /content/stylegan2-ada-pytorch/train.py --snap 25 --resume /content/drive/MyDrive/data/gan/bikes/00000-bikes-auto1/network-snapshot-000000.pkl --outdir /content/drive/MyDrive/data/gan/experiments --data /content/drive/MyDrive/data/gan/dataset/bikes
# Out:
# /usr/bin/python3: can't open file '/content/stylegan2-ada-pytorch/train.py': [Errno 2] No such file or directory

# %%
# Define dataset path as .zip file of training bike images
dataset_path = '/content/drive/MyDrive/data/bike_images/shoes.zip'
# Define resume from path as .pkl file after training in the results folder
resume_from = './content/drive/MyDrive/data/gan/experiments/00005-bikes-auto1-resumecustom/full-bike-network-snapshot-004096.pkl'
# Adjust aug strength as necessary
aug_strength = 0.0
train_count = 0

# Set default values as below
mirror_x = True
mirror_y = False
gamma_value = 50
augs = 'bg'
config = '11gb-gpu'
snapshot_count = 4

# %% [markdown]
# ## Train with this pipe command

# %%
# !python train.py --gpus=1 --cfg=$config --metrics=None --outdir=./results --data=$dataset_path --snap=$snapshot_count --augpipe=$augs --initstrength=$aug_strength --gamma=$gamma_value --mirror=$mirror_x --mirrory=False --nkimg=$train_count
# Out:
# /usr/local/lib/python3.8/dist-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.24.1
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Usage: train.py [OPTIONS]
# Try 'train.py --help' for help.
#
# Error: --data: cannot identify image file <zipfile.ZipExtFile name='__MACOSX/shoes/._35383_resized.jpg' mode='r' compress_type=deflate>

# %% [markdown]
# Output images as desired with the following pipe command

# %% [markdown]
# ## Generate 1000 StyleGan Generated Images

# %%
# !python generate.py --outdir=/content/drive/MyDrive/bikes_metadata/images --trunc=0.5 --seeds=1-1001 --network=/content/drive/MyDrive/data/gan/bikes/full-bike-network-snapshot.pkl
# Out:
# generate.py:59: SyntaxWarning: "is not" with a literal. Did you mean "!="?
#   elif(len(seeds) is not 3):
# Traceback (most recent call last):
#   File "generate.py", line 25, in <module>
#     from opensimplex import OpenSimplex
#   File "/usr/local/lib/python3.8/dist-packages/opensimplex/__init__.py", line 4, in <module>
#     from .api import *
#   File "/usr/local/lib/python3.8/dist-packages/opensimplex/api.py", line 2, in <module>
#     from .internals import _init, _noise2, _noise3, _noise4, _noise2a, _noise3a, _noise4a
#   File "/usr/local/lib/python3.8/dist-packages/opensimplex/internals.py", line 9, in <module>
#     from numba import njit, prange
#   File "/usr/local/lib/python3.8/dist-packages/numba/__init__.py", line 42, in <module>
#     from numba.np.ufunc import (vectorize, guvectorize, threading_layer,
#   File "/usr/local/lib/python3.8/dist-packages/numba/np/ufunc/__init__.py", line 3, in <module>
# ...

# %% [markdown]
# ## Generate Latents for Images in StyleGan2

# %%
# !python latents.py --outdir=/content/drive/MyDrive/bikes_metadata/latents --trunc=0.5 --seeds=1-1001 --network=/content/drive/MyDrive/data/gan/bikes/full-bike-network-snapshot.pkl
# Out:
# Loading networks from "/content/drive/MyDrive/data/gan/bikes/full-bike-network-snapshot.pkl"...
# /usr/local/lib/python3.8/dist-packages/torch/cuda/__init__.py:104: UserWarning:
# A100-SXM4-40GB with CUDA capability sm_80 is not compatible with the current PyTorch installation.
# The current PyTorch install supports CUDA capabilities sm_37 sm_50 sm_60 sm_70.
# If you want to use the A100-SXM4-40GB GPU with PyTorch, please check the instructions at https://pytorch.org/get-started/locally/
#
#   warnings.warn(incompatible_device_warn.format(device_name, capability, " ".join(arch_list), device_name))
# Generating latents for seed 1 (0/1001) ...
# Generating latents for seed 2 (1/1001) ...
# Generating latents for seed 3 (2/1001) ...
# Generating latents for seed 4 (3/1001) ...
# Generating latents for seed 5 (4/1001) ...
# Generating latents for seed 6 (5/1001) ...
# Generating latents for seed 7 (6/1001) ...
# Generating latents for seed 8 (7/1001) ...
# ...
